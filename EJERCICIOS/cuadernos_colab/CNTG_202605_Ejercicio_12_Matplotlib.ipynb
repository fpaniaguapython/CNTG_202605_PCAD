# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://fpaniaguapython.github.io/datos/datos_ventas_ancho.csv')
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   mes          12 non-null     object
#  1   extremadura  12 non-null     int64
#  2   galicia      12 non-null     int64
#  3   madrid       12 non-null     int64
#  4   melilla      12 non-null     int64
#  5   navarra      12 non-null     int64
#  6   pais_vasco   12 non-null     int64
#  7   la_rioja     12 non-null     int64
#  8   ceuta        12 non-null     int64
# dtypes: int64(8), object(1)
# memory usage: 996.0+ bytes
# None
#        mes  extremadura  galicia  madrid  melilla  navarra  pais_vasco  \
# 0    enero          120      210     480       15       55         190
# 1  febrero          110      200     450       14       53         180
# 2    marzo          130      225     520       16       60         205
# ...

# %%
# plt.boxplot(df['galicia'])
df.drop('mes', axis=1, inplace=True)
plt.figure(figsize=(10,10), facecolor='#901010') # RGB
#plt.figure(figsize=(10,10), facecolor='orange') # nombre
plt.xticks(rotation=45)
plt.boxplot(df)
plt.show()
