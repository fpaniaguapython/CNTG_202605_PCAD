# %%
from io import StringIO
import requests
import pandas as pd

URL = 'https://es.wikipedia.org/wiki/Anexo:Pa%C3%ADses_por_PIB_(nominal)_per_c%C3%A1pita'

headers = {
    "User-Agent": "MiAplicacion/1.0 (admin@midominio.com)"
}

response = requests.get(url=URL, headers=headers)

if response.status_code == 200:
  datos = pd.read_html(StringIO(response.text))
  #print(datos)
  dataframe_buscado = datos[1]
  print(dataframe_buscado.info())
else:
    print('Ha ocurrido un error', response.status_code)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 7 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   (País/Territorio, País/Territorio)                  223 non-null    object
#  1   (FMI[1][2], Estimado)                               223 non-null    object
#  2   (FMI[1][2], Año)                                    223 non-null    object
#  3   (Banco Mundial[3], Estimado)                        223 non-null    object
#  4   (Banco Mundial[3], Año)                             223 non-null    object
#  5   (Organización de las Naciones Unidas[4], Estimado)  223 non-null    object
#  6   (Organización de las Naciones Unidas[4], Año)       223 non-null    object
# dtypes: object(7)
# memory usage: 12.4+ KB
# None
