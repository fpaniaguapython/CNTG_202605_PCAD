# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split # Troceador de datos de entrenamiento
import sklearn.linear_model as lm
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import joblib # Librería que permite almacenar los modelos serializados

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Obtener el modelo

# %%
modelo = joblib.load("/content/drive/MyDrive/modelo_regresion_datos_medicos.pkl")

# %% [markdown]
# # Obtener predicción

# %%
nuevo = pd.DataFrame({
    'horas_sueño': [7],
    'peso': [80],
    'horas_ejercicio': [2],
    'edad': [30],
    'genero_Hombre': [True],
    'genero_Mujer': [False]
})

prediccion = modelo.predict(nuevo)

print(prediccion)
# Out:
# [178.58442186]
