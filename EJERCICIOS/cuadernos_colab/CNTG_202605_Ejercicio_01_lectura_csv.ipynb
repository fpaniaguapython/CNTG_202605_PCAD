# %% [markdown]
# # Obtención de datos de la web 👍

# %% [markdown]
# ## Importar librerías

# %%
import pandas as pd

# %% [markdown]
# ## Definir las constantes

# %%
URL = 'https://fpaniaguapython.github.io/datos/CCAA-ULTIMOS-DOCE-MESES-LAPTOP-H55DSDJ2.csv'

# %% [markdown]
# ## Obtener el fichero CSV

# %%
datos = pd.read_csv(URL, sep=';')
datos
# Out:
#                comunidad   may-25   jun-25   jul-25   ago-25   sep-25  \
# 0                  Total  112.811  119.145   98.335   61.315   85.167
# 1              ANDALUCIA    9.200   10.504   10.582    7.248    9.472
# 2                 ARAGON    1.401    1.594    1.628    1.135    1.448
# 3               ASTURIAS  918.000    1.304    1.512    1.511    1.429
# 4               CANARIAS    4.176    6.646    5.889    3.304    4.522
# 5              CANTABRIA  752.000  796.000  790.000  730.000  770.000
# 6        CASTILLA Y LEON    2.153    2.397    2.465    1.994    2.348
# 7     CASTILLA-LA MANCHA    2.075    2.216    2.677    2.155    2.254
# 8               CATALUÑA   11.947   12.485   12.995    8.255   11.551
# 9                  CEUTA   86.000   83.000  108.000   68.000   79.000
# 10   COMUNIDAD DE MADRID   52.701   56.668   38.101   20.554   32.549
# 11  COMUNIDAD VALENCIANA   16.160   12.090    9.621    5.985    7.951
# ...
